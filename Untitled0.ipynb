# %%
import os
print(os.getcwd())
# Out:
# /content

# %% [markdown]
# Importando

# %% [markdown]
# importando bibliotecas necessárias para processamento de imagem.

# %%
import tensorflow.keras as tf
 
import numpy as np
from PIL import Image
import requests
from io import BytesIO
from google.colab.patches import cv2_imshow

# %%
response = requests.get("https://img.ibxk.com.br/2020/01/02/02222020370194.jpg")
imagem_orig = Image.open(BytesIO(response.content))
display(imagem_orig)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x640 at 0x7F45593FB990>
