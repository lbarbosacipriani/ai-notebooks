# %%
# !pip3 install python3-opencv
# Out:
# ERROR: Could not find a version that satisfies the requirement python3-opencv (from versions: none)
# ERROR: No matching distribution found for python3-opencv
